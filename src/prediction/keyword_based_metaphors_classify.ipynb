# %%
import pandas as pd
import sqlite3
import pandas as pd
cnx = sqlite3.connect('../database/output/papers.db')

papers = pd.read_sql_query("SELECT * FROM paper", cnx)
authors =  pd.read_sql_query("SELECT * FROM author", cnx)
authors_to_papers =  pd.read_sql_query("SELECT * FROM paper_author", cnx)
keywords_to_papers = pd.read_sql_query("SELECT * FROM paper_keyword", cnx)
keywords =  pd.read_sql_query("SELECT * FROM keyword", cnx)

danny = pd.read_csv("keywords_tokenized_5_or_more_danny.csv")
reconciled = pd.read_csv("diffs_reconciled.csv")
# Out:
#                word  frequency  war  disease  markets
# 0               and        826  0.0      0.0      0.0
# 1       information        783  0.0      0.0      0.0
# 2            health        779  0.0      1.0      0.0
# 3                of        744  0.0      0.0      0.0
# 4            social        638  0.0      0.0      0.0
# ...             ...        ...  ...      ...      ...
# 2999  antimicrobial          5  NaN      NaN      NaN
# 3000      tenofovir          5  NaN      NaN      NaN
# 3001    intraocular          5  NaN      NaN      NaN
# 3002          harms          5  NaN      NaN      NaN
# 3003         layers          5  NaN      NaN      NaN
#
# [3004 rows x 5 columns]

# %%
danny = danny[danny.index < 1500]

# %%
reconciled = reconciled[[
    "word",
    "war_reconciled",
    "disease_reconciled",
    "markets_reconciled"
]]

# %%
reconciled = reconciled.rename(columns={
    "war_reconciled": "war",
    "disease_reconciled": "disease",
    "markets_reconciled": "markets"
})

# %%
merged = danny.merge(reconciled, on="word", how="left", suffixes=("", "_updated"))

# %%
for col in ["war", "disease", "markets"]:
    merged[col] = merged[f"{col}_updated"].combine_first(merged[col])
    merged = merged.drop(columns=[f"{col}_updated"])

# %%
merged.to_csv('merged.csv')

# %%
score_cols = ["war", "disease", "markets"]

# Build dict: { word : {war: x, disease: y, markets: z} }
score_lookup = (
    merged
    .set_index("word")[score_cols]
    .to_dict(orient="index")
)

# %%
from nltk import word_tokenize

def score_keyword(kw):
    tokens = word_tokenize(str(kw).lower())

    # initialize accumulators
    totals = {col: 0 for col in score_cols}
    totals["token_count"] = len(tokens)

    # accumulate scores
    for tok in tokens:
        if tok in score_lookup:
            for col in score_cols:
                totals[col] += score_lookup[tok][col]

    return totals

# %%
scores = keywords["keyword"].apply(score_keyword)
scores_df = scores.apply(pd.Series)

keywords_scored = pd.concat([keywords, scores_df], axis=1)
keywords_scored
# Out:
#           id                          keyword  war  disease  markets  \
# 0          1  corporate social responsibility  0.0      0.0      0.0
# 1          2                         covid-19  0.0      1.0      0.0
# 2          3     ethical crisis communication  1.0      0.0      1.0
# 3          4                        fake news  0.0      0.0      0.0
# 4          5                        infodemic  0.0      1.0      0.0
# ...      ...                              ...  ...      ...      ...
# 40457  40458              tubal sterilization  0.0      0.0      0.0
# 40458  40459                      ejaculation  0.0      0.0      0.0
# 40459  40460                     foreign body  1.0      1.0      0.0
# 40460  40461       uterine tube sterilization  0.0      1.0      0.0
# 40461  40462             sterilization, tubal  0.0      0.0      0.0
#
#        token_count
# 0              3.0
# 1              1.0
# 2              3.0
# 3              2.0
# 4              1.0
# ...            ...
# 40457          2.0
# 40458          1.0
# 40459          2.0
# 40460          3.0
# 40461          3.0
#
# [40462 rows x 6 columns]

# %%
keywords_to_papers
# Out:
#                                 paper_id  keyword_id
# 0              10.1515/9783110752427-031           1
# 1              10.1515/9783110752427-031           2
# 2              10.1515/9783110752427-031           3
# 3              10.1515/9783110752427-031           4
# 4              10.1515/9783110752427-031           5
# ...                                  ...         ...
# 222115  10.1016/j.fertnstert.2010.05.031        7072
# 222116  10.1016/j.fertnstert.2010.05.031        2294
# 222117  10.1016/j.fertnstert.2010.05.031        3993
# 222118  10.1016/j.fertnstert.2010.05.031       40462
# 222119  10.1016/j.fertnstert.2010.05.031         279
#
# [222120 rows x 2 columns]

# %%
merged = keywords_to_papers.merge(
    keywords_scored,
    left_on="keyword_id",
    right_on="id",
    how="left"
)

paper_scores = (
    merged.groupby("paper_id")[score_cols]
          .sum()
          .reset_index()
)

token_counts = (
    merged.groupby("paper_id")["token_count"]
          .sum()
          .rename("token_count_total")
          .reset_index()
)

# %%
paper_scores = paper_scores.merge(token_counts, on="paper_id", how="left")

for col in score_cols:   # ["war", "disease", "markets"]
    paper_scores[col + "_norm"] = (
        paper_scores[col] / paper_scores["token_count_total"]
    )

# %%
paper_scores.to_csv("paper_metaphor_scores.csv")

# %%
paper_scores
# Out:
#                           paper_id    war  disease  markets  \
# 0                                   404.0   1108.0    690.0
# 1      10.1001/amajethics.2023.204    0.0      3.0      3.0
# 2      10.1001/amajethics.2023.210    1.0      7.0      1.0
# 3      10.1001/amajethics.2023.228    1.0      2.0      1.0
# 4          10.1001/jama.2018.16865    2.0     14.0      4.0
# ...                            ...    ...      ...      ...
# 12253      10.9745/GHSP-D-21-00031    2.0      7.0      6.0
# 12254      10.9745/GHSP-D-22-00447    0.0      8.0      0.0
# 12255      10.9745/GHSP-D-23-00146    0.0      8.0      0.0
# 12256   10.9781/ijimai.2020.06.003    0.0      0.0      0.0
# 12257        10.9788/TP2018.4-03En    0.0      0.0      0.0
#
#        token_count_total  war_norm  disease_norm  markets_norm
# 0                11696.0  0.034542      0.094733      0.058995
# 1                   21.0  0.000000      0.142857      0.142857
# 2                   16.0  0.062500      0.437500      0.062500
# 3                   10.0  0.100000      0.200000      0.100000
# 4                   52.0  0.038462      0.269231      0.076923
# ...                  ...       ...           ...           ...
# 12253               47.0  0.042553      0.148936      0.127660
# 12254               21.0  0.000000      0.380952      0.000000
# 12255               23.0  0.000000      0.347826      0.000000
# 12256                8.0  0.000000      0.000000      0.000000
# 12257                6.0  0.000000      0.000000      0.000000
#
# [12258 rows x 8 columns]

# %%
norm_cols = ["war_norm", "disease_norm", "markets_norm"]
def get_top_and_bottom(df, col, n=5):
    top = df.sort_values(col, ascending=False).head(n)
    bottom = df.sort_values(col, ascending=True).head(n)
    return top, bottom

# %%
results = {}

for col in norm_cols:
    top, bottom = get_top_and_bottom(paper_scores, col, n=5)
    results[col] = {
        "top": top,
        "bottom": bottom
    }

# %%
output_frames = []

for col in norm_cols:
    top = paper_scores.sort_values(col, ascending=False).head(5).assign(rank_type=f"{col}_top5")
    bottom = paper_scores.sort_values(col, ascending=True).head(5).assign(rank_type=f"{col}_bottom5")
    output_frames.extend([top, bottom])

summary_df = pd.concat(output_frames, ignore_index=True)

# %%
summary_df.to_csv("paper_score_extremes.csv", index=False)

# %%
def score_text(text):
    tokens = word_tokenize(str(text).lower())

    # accumulator for scores
    totals = {col: 0 for col in score_cols}
    totals["token_count"] = len(tokens)

    for tok in tokens:
        if tok in score_lookup:     # same lookup dict as keyword scoring
            for col in score_cols:
                totals[col] += score_lookup[tok][col]

    return totals

# %%
papers["text"] = papers["title"].fillna("") + " " + papers["abstract"].fillna("")

# %%
import numpy as np

paper_scores = papers["text"].apply(score_text)
paper_scores_df = paper_scores.apply(pd.Series)

for col in score_cols:
    paper_scores_df[col + "_norm"] = (
        paper_scores_df[col] / paper_scores_df["token_count"]
    )
    paper_scores_df[col + "_sqrt_norm"] = (
        paper_scores_df[col] / np.sqrt(paper_scores_df["token_count"])
    )

# %%
papers_scored = pd.concat([papers, paper_scores_df], axis=1)

# %%
papers_scored = papers_scored[papers_scored.abstract != '[No abstract available]']

# %%
results = {}

cols_sqrt = ['war_sqrt_norm', 'disease_sqrt_norm', 'markets_sqrt_norm']

# use unnormalized to avoid prioritizing short or nonexistent abstracts
# use normalized to avoid prioritizing long abstracts
# use sqrt norm as an attempt at a middle ground btw prioritizing long and short abstracts
for col in norm_cols:
    top, bottom = get_top_and_bottom(papers_scored, col, n=5)
    results[col] = {"top": top, "bottom": bottom}

# %%
frames = []

for col in norm_cols:
    top = papers_scored.sort_values(col, ascending=False).head(5)
    top = top.assign(rank_type=f"{col}_top5")
    
    bottom = papers_scored.sort_values(col, ascending=True).head(5)
    bottom = bottom.assign(rank_type=f"{col}_bottom5")
    
    frames.extend([top, bottom])

summary_df = pd.concat(frames, ignore_index=True)

# %%
summary_df.to_csv("abstract_title_scores_top_bottom_no_missing_abstracts.csv")

# %%
summary_df
# Out:
#                                        doi  \
# 0             10.1080/14742837.2013.807730
# 1               10.1002/9781119289142.ch11
# 2                    10.4324/9781003432630
# 3                  10.55540/0031-1723.3139
# 4            10.1080/02185377.2021.1979062
# 5                10.1177/15579883221094716
# 6                   10.1542/peds.2017-2241
# 7        10.1109/BdKCSE59280.2023.10339741
# 8                10.1109/JBHI.2020.3032479
# 9   10.22201/iibi.24488321xe.2020.84.58115
# 10              10.1016/j.japh.2023.01.003
# 11                  10.1093/crocol/otaa026
# 12         10.1634/theoncologist.2017-0444
# 13               10.1016/j.nwh.2017.12.008
# 14              10.1007/s10654-020-00671-y
# 15            10.1007/978-981-16-5792-4_19
# 16         10.1016/j.biopsycho.2021.108026
# 17               10.1504/IJWBC.2019.098692
# 18            10.1007/978-3-031-10865-5_10
# 19            10.1016/j.jarmac.2020.10.002
# 20           10.1016/j.jpolmod.2022.02.001
# 21           10.1080/01900692.2021.2004605
# 22                       10.1201/b18049-70
# 23         10.1088/1755-1315/1098/1/012007
# 24                 10.4324/9780429353383-2
# 25                       10.1002/jcpy.1135
# 26                   10.34190/ICCWS.20.023
# 27                      10.1117/12.2664994
# 28            10.1007/978-3-030-39512-4_93
# 29           10.22038/abjs.2019.34844.1916
#
#                                                 title  \
# 0   Law as Movement Strategy: How the Islamophobia...
# 1   National Strategy for Combating Terrorism, 200...
# 2           Memetic War: Online Resistance in Ukraine
# 3   On “The Alt-Right Movement and US National Sec...
# 4   COVID-19 vaccination campaign trends and chall...
# 5   Assessing Vasectomy-Related Information on You...
# 6   How parents of children with cancer learn abou...
# 7   Contagion Propagation with Rule-Based Reasonin...
# 8   Automatically Assessing Quality of Online Heal...
# 9   Information reliability: Criteria to identify ...
# 10  The impact of COVID-19 on select consideration...
# 11  The risk of SARS-CoV-2 in immunosuppressed IBD...
# 12  Barriers and Facilitators to Cervical Cancer S...
# 13  A Literature Review of Cervical Cancer Screeni...
# 14  Vaccine hesitancy: the next challenge in the f...
# 15  Post-truth of Female Empowerment in the Fake N...
# 16  Reliability of the N2-component in a modified ...
# 17  Racism and social media: A study in Indian con...
# 18  Conclusions: My Liberation Is Bound Up with Yours
# 19  Truncating Bar Graphs Persistently Misleads Vi...
# 20  The evolving risks of the 21st century and the...
# 21  Trust in Government during COVID-19 Pandemic i...
# 22  Influence of supply chain integration on busin...
# 23  Integrating fuzzy logic and house risk method ...
# 24  Consequences of federal government information...
# 25  How Stories in Memory Perpetuate the Continued...
# 26  A warfare domain approach to the disinformatio...
# 27  The relationship between social media use and ...
# 28  A counterattack of misinformation: How the inf...
# 29  Misinformation in news coverage of professiona...
#
#                                              abstract  year  community  \
# 0   Islamophobia is a strategic movement led by a ...  2014       7609
# 1   This chapter details the 2006 National Strateg...  2017       7202
# 2   Memetic War analyses memetic warfare included ...  2023       1547
# 3   This commentary responds to Matthew Valasik an...  2022       3760
# 4   How successful have countries in Asia been at ...  2021       5170
# 5   This study aims to critically appraise the qua...  2022       3097
# 6   Objectives: To determine which prognostic info...  2018       7053
# 7   In recent years, and especially during the on-...  2023       1364
# 8   Today Information in the world wide web is ove...  2021       6740
# 9   The article presents information reliability c...  2020       6291
# 10  The coronavirus disease 2019 (COVID-19) pandem...  2023        879
# 11  This is a rapid review of the risk of infectio...  2020       5987
# 12  Background: This study was conducted to identi...  2019       6769
# 13  Most female-to-male (FTM) transgender men reta...  2018       6975
# 14  Vaccine hesitancy remains a barrier to full po...  2020       5746
# 15  This study investigates the fake news generate...  2022       3893
# 16  Research on deception focused on the investiga...  2021       4883
# 17  Racism is a kind of hatred behaviour, exhibite...  2019       2991
# 18  This chapter draws conclusions about incorpora...  2023       2091
# 19  Data visualizations and graphs are increasingl...  2021       1921
# 20  Risk management institutions can be reinvented...  2022       2728
# 21  The study aims to understand social media user...  2023       2145
# 22  As an important trend in business management, ...  2015       7542
# 23  Risk management is very important for all orga...  2022       3490
# 24  Prompted by ideological considerations, the Re...  2019       6378
# 25  People often encounter information that they s...  2020       6080
# 26  Land and sea were the original warfighting dom...  2020       6336
# 27  This paper is concerned with the correlation i...  2023       1622
# 28  This study aims to investigate how the issue o...  2020       6342
# 29  Background: The general population’s understan...  2020       6347
#
#                                                  text   war  disease  markets  \
# 0   Law as Movement Strategy: How the Islamophobia...  18.0      0.0      1.0
# 1   National Strategy for Combating Terrorism, 200...  20.0      2.0      9.0
# 2   Memetic War: Online Resistance in Ukraine Meme...  20.0      0.0      4.0
# 3   On “The Alt-Right Movement and US National Sec...   6.0      0.0      2.0
# 4   COVID-19 vaccination campaign trends and chall...  15.0     13.0      8.0
# 5   Assessing Vasectomy-Related Information on You...   0.0      6.0      1.0
# 6   How parents of children with cancer learn abou...   0.0     12.0      1.0
# 7   Contagion Propagation with Rule-Based Reasonin...   0.0      5.0      2.0
# 8   Automatically Assessing Quality of Online Heal...   0.0      8.0      1.0
# 9   Information reliability: Criteria to identify ...   0.0      1.0      0.0
# 10  The impact of COVID-19 on select consideration...   2.0     48.0      6.0
# 11  The risk of SARS-CoV-2 in immunosuppressed IBD...   0.0     23.0      5.0
# 12  Barriers and Facilitators to Cervical Cancer S...   2.0     53.0      1.0
# 13  A Literature Review of Cervical Cancer Screeni...   0.0     24.0      3.0
# 14  Vaccine hesitancy: the next challenge in the f...   3.0     31.0      4.0
# 15  Post-truth of Female Empowerment in the Fake N...   0.0      0.0      3.0
# 16  Reliability of the N2-component in a modified ...   2.0      0.0      0.0
# 17  Racism and social media: A study in Indian con...   0.0      0.0      0.0
# 18  Conclusions: My Liberation Is Bound Up with Yo...   6.0      0.0      1.0
# 19  Truncating Bar Graphs Persistently Misleads Vi...   1.0      0.0      1.0
# 20  The evolving risks of the 21st century and the...   3.0     13.0     17.0
# 21  Trust in Government during COVID-19 Pandemic i...  17.0      5.0     22.0
# 22  Influence of supply chain integration on busin...   1.0      1.0     13.0
# 23  Integrating fuzzy logic and house risk method ...   3.0     16.0     21.0
# 24  Consequences of federal government information...   7.0      1.0     16.0
# 25  How Stories in Memory Perpetuate the Continued...   3.0      0.0      0.0
# 26  A warfare domain approach to the disinformatio...   7.0      1.0      0.0
# 27  The relationship between social media use and ...   1.0      7.0      0.0
# 28  A counterattack of misinformation: How the inf...   1.0      0.0      0.0
# 29  Misinformation in news coverage of professiona...   0.0     10.0      0.0
#
#     token_count  war_norm  war_sqrt_norm  disease_norm  disease_sqrt_norm  \
# 0         131.0  0.137405       1.572667      0.000000           0.000000
# 1         168.0  0.119048       1.543033      0.011905           0.154303
# 2         178.0  0.112360       1.499063      0.000000           0.000000
# 3          59.0  0.101695       0.781133      0.000000           0.000000
# 4         155.0  0.096774       1.204829      0.083871           1.044185
# 5         308.0  0.000000       0.000000      0.019481           0.341882
# 6         328.0  0.000000       0.000000      0.036585           0.662589
# 7         155.0  0.000000       0.000000      0.032258           0.401610
# 8         211.0  0.000000       0.000000      0.037915           0.550743
# 9         198.0  0.000000       0.000000      0.005051           0.071067
# 10        225.0  0.008889       0.133333      0.213333           3.200000
# 11        108.0  0.000000       0.000000      0.212963           2.213176
# 12        280.0  0.007143       0.119523      0.189286           3.167356
# 13        129.0  0.000000       0.000000      0.186047           2.113082
# 14        168.0  0.017857       0.231455      0.184524           2.391702
# 15        254.0  0.000000       0.000000      0.000000           0.000000
# 16        204.0  0.009804       0.140028      0.000000           0.000000
# 17        183.0  0.000000       0.000000      0.000000           0.000000
# 18        165.0  0.036364       0.467099      0.000000           0.000000
# 19        187.0  0.005348       0.073127      0.000000           0.000000
# 20        123.0  0.024390       0.270501      0.105691           1.172171
# 21        191.0  0.089005       1.230077      0.026178           0.361787
# 22        114.0  0.008772       0.093659      0.008772           0.093659
# 23        186.0  0.016129       0.219971      0.086022           1.173177
# 24        146.0  0.047945       0.579324      0.006849           0.082761
# 25        203.0  0.014778       0.210559      0.000000           0.000000
# 26        340.0  0.020588       0.379628      0.002941           0.054233
# 27        176.0  0.005682       0.075378      0.039773           0.527645
# 28        116.0  0.008621       0.092848      0.000000           0.000000
# 29        246.0  0.000000       0.000000      0.040650           0.637577
#
#     markets_norm  markets_sqrt_norm             rank_type
# 0       0.007634           0.087370         war_norm_top5
# 1       0.053571           0.694365         war_norm_top5
# 2       0.022472           0.299813         war_norm_top5
# 3       0.033898           0.260378         war_norm_top5
# 4       0.051613           0.642575         war_norm_top5
# 5       0.003247           0.056980      war_norm_bottom5
# 6       0.003049           0.055216      war_norm_bottom5
# 7       0.012903           0.160644      war_norm_bottom5
# 8       0.004739           0.068843      war_norm_bottom5
# 9       0.000000           0.000000      war_norm_bottom5
# 10      0.026667           0.400000     disease_norm_top5
# 11      0.046296           0.481125     disease_norm_top5
# 12      0.003571           0.059761     disease_norm_top5
# 13      0.023256           0.264135     disease_norm_top5
# 14      0.023810           0.308607     disease_norm_top5
# 15      0.011811           0.188237  disease_norm_bottom5
# 16      0.000000           0.000000  disease_norm_bottom5
# 17      0.000000           0.000000  disease_norm_bottom5
# 18      0.006061           0.077850  disease_norm_bottom5
# 19      0.005348           0.073127  disease_norm_bottom5
# 20      0.138211           1.532838     markets_norm_top5
# 21      0.115183           1.591864     markets_norm_top5
# 22      0.114035           1.217562     markets_norm_top5
# 23      0.112903           1.539795     markets_norm_top5
# 24      0.109589           1.324169     markets_norm_top5
# 25      0.000000           0.000000  markets_norm_bottom5
# 26      0.000000           0.000000  markets_norm_bottom5
# 27      0.000000           0.000000  markets_norm_bottom5
# 28      0.000000           0.000000  markets_norm_bottom5
# 29      0.000000           0.000000  markets_norm_bottom5
